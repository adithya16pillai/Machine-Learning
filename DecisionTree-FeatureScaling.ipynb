# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df=pd.read_csv(r'C:\Users\adith\Downloads\pima-indians-diabetes.csv')
df.columns=col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
df.head(10)
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         1       85  66    29        0  26.6     0.351   31      0
# 1         8      183  64     0        0  23.3     0.672   32      1
# 2         1       89  66    23       94  28.1     0.167   21      0
# 3         0      137  40    35      168  43.1     2.288   33      1
# 4         5      116  74     0        0  25.6     0.201   30      0
# 5         3       78  50    32       88  31.0     0.248   26      1
# 6        10      115   0     0        0  35.3     0.134   29      0
# 7         2      197  70    45      543  30.5     0.158   53      1
# 8         8      125  96     0        0   0.0     0.232   54      1
# 9         4      110  92     0        0  37.6     0.191   30      0

# %%
# Prepare data
X = df.iloc[:, :-1].values  # Features ('pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age')
y = df.iloc[:, -1].values  # Labels ('label')

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
clf = DecisionTreeClassifier()

#Training the decision tree classifier. 
clf.fit(X_train, y_train)

#Predicting labels on the test set.
y_pred1 =  clf.predict(X_test)

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

y_pred_test =  clf.predict(X_test)

from sklearn.metrics import accuracy_score
print('Accuracy Score on test data: ', accuracy_score(y_true=y_test, y_pred=y_pred_test)*100)
# Out:
# Accuracy Score on test data:  60.3896103896104

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc.transform(X_test[:, 3:])

# %%
print(X_train)
# Out:
# [[ 2.00000000e+00  1.97000000e+02  7.00000000e+01 ...  3.06901241e-01
#    3.35391284e-01  2.51066174e+00]
#  [ 1.30000000e+01  1.58000000e+02  1.14000000e+02 ...  1.29761043e+00
#   -6.61181556e-01  9.45452314e-01]
#  [ 4.00000000e+00  1.56000000e+02  7.50000000e+01 ...  2.07974926e+00
#   -7.20725217e-01 -9.80206375e-02]
#  ...
#  [ 3.00000000e+00  1.71000000e+02  7.20000000e+01 ...  1.24402180e-01
#   -8.42946414e-01 -7.93669272e-01]
#  [ 0.00000000e+00  1.23000000e+02  8.80000000e+01 ...  3.72079477e-01
#   -8.49214168e-01 -3.58888875e-01]
#  [ 1.00000000e+00  1.44000000e+02  8.20000000e+01 ...  1.79296502e+00
#   -4.16739161e-01  1.11936447e+00]]

# %%
print(X_test)
# Out:
# [[ 1.00000000e+00  1.19000000e+02  4.40000000e+01 ...  4.11186419e-01
#   -5.89102389e-01 -7.06713192e-01]
#  [ 5.00000000e+00  1.62000000e+02  1.04000000e+02 ...  6.97970658e-01
#   -9.93372503e-01  1.64110095e+00]
#  [ 1.00000000e+00  1.17000000e+02  8.80000000e+01 ...  2.80829947e-01
#   -2.03635535e-01  5.97627997e-01]
#  ...
#  [ 1.00000000e+00  1.26000000e+02  5.60000000e+01 ... -4.75237592e-01
#    1.04364745e+00 -1.05453751e+00]
#  [ 6.00000000e+00  1.07000000e+02  8.80000000e+01 ...  5.80649833e-01
#    8.11740567e-01 -1.84976717e-01]
#  [ 1.30000000e+01  1.04000000e+02  7.20000000e+01 ... -1.49346412e-01
#   -9.33516989e-03  4.23715838e-01]]

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

y_pred_test =  clf.predict(X_test)
#y_pred_test =  clf.predict(

from sklearn.metrics import accuracy_score
print('Accuracy Score on test data: ', accuracy_score(y_true=y_test, y_pred=y_pred_test)*100)
# Out:
# Accuracy Score on test data:  61.038961038961034

# %%
# Convert class names to strings
classes = ['0', '1']  # Replace these with actual class names if they exist
features = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age']
# Plot the decision tree
plt.figure(figsize=(19, 12))
plot_tree(clf, feature_names=features, class_names=classes, filled=True, max_depth=4)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler #Using MinMax
sc1 = MinMaxScaler()
X_train[:, 3:] = sc1.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc1.transform(X_test[:, 3:])

# %%
print(X_train)
# Out:
# [[2.00000000e+00 1.97000000e+02 7.00000000e+01 ... 5.17138599e-01
#   2.10188356e-01 8.03921569e-01]
#  [1.30000000e+01 1.58000000e+02 1.14000000e+02 ... 6.30402385e-01
#   7.40582192e-02 4.50980392e-01]
#  [4.00000000e+00 1.56000000e+02 7.50000000e+01 ... 7.19821162e-01
#   6.59246575e-02 2.15686275e-01]
#  ...
#  [3.00000000e+00 1.71000000e+02 7.20000000e+01 ... 4.96274218e-01
#   4.92294521e-02 5.88235294e-02]
#  [0.00000000e+00 1.23000000e+02 8.80000000e+01 ... 5.24590164e-01
#   4.83732877e-02 1.56862745e-01]
#  [1.00000000e+00 1.44000000e+02 8.20000000e+01 ... 6.87034277e-01
#   1.07448630e-01 4.90196078e-01]]

# %%
print(X_test)
# Out:
# [[1.00000000e+00 1.19000000e+02 4.40000000e+01 ... 5.29061103e-01
#   8.39041096e-02 7.84313725e-02]
#  [5.00000000e+00 1.62000000e+02 1.04000000e+02 ... 5.61847988e-01
#   2.86815068e-02 6.07843137e-01]
#  [1.00000000e+00 1.17000000e+02 8.80000000e+01 ... 5.14157973e-01
#   1.36558219e-01 3.72549020e-01]
#  ...
#  [1.00000000e+00 1.26000000e+02 5.60000000e+01 ... 4.27719821e-01
#   3.06934932e-01 0.00000000e+00]
#  [6.00000000e+00 1.07000000e+02 8.80000000e+01 ... 5.48435171e-01
#   2.75256849e-01 1.96078431e-01]
#  [1.30000000e+01 1.04000000e+02 7.20000000e+01 ... 4.64977645e-01
#   1.63099315e-01 3.33333333e-01]]

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)

y_pred_test =  clf.predict(X_test)

from sklearn.metrics import accuracy_score
print('Accuracy Score on test data: ', accuracy_score(y_true=y_test, y_pred=y_pred_test)*100)
# Out:
# Accuracy Score on test data:  61.038961038961034
